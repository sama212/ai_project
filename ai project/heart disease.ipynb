# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score ,precision_score, recall_score, f1_score

# %% [markdown]
# # preprocessing

# %%
data = pd.read_csv('heart.csv')

# %%
data.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data_dup = data.duplicated().any()
data_dup
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
cate_val=[] 
cont_val=[]  

for column in data.columns:
    if data [column].nunique () <=10:
        cate_val.append (column)
    else:
        cont_val.append (column)

# %%
cate_val
# Out:
# ['gender', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data ['cp'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
data['target'].value_counts().plot(kind='pie', autopct='%1.0f%%')
# Out:
# <Axes: ylabel='target'>

# %%
# print first 5 rows of the dataset
data.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52       1   0       125   212    0        1      168      0      1.0
# 1   53       1   0       140   203    1        0      155      1      3.1
# 2   70       1   0       145   174    0        1      125      1      2.6
# 3   61       1   0       148   203    0        1      161      0      0.0
# 4   62       0   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
# print last 5 rows of the dataset
data.tail()
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 723   68       0   2       120   211    0        0      115      0      1.5
# 733   44       0   2       108   141    0        1      175      0      0.6
# 739   52       1   0       128   255    0        1      161      1      0.0
# 843   59       1   3       160   273    0        0      125      0      0.0
# 878   54       1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 723      1   0     2       1
# 733      1   0     2       1
# 739      2   1     3       0
# 843      2   0     2       0
# 878      1   1     3       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   gender    302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
#analize data
# statistical measures about the data
data.describe()
# Out:
#              age      gender          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
st = StandardScaler()
data[cont_val] = st.fit_transform(data[cont_val])

# %%
data.head()
# Out:
#         age  gender  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0 -0.267966       1   0 -0.376556 -0.667728    0        1  0.806035      0
# 1 -0.157260       1   0  0.478910 -0.841918    1        0  0.237495      1
# 2  1.724733       1   0  0.764066 -1.403197    0        1 -1.074521      1
# 3  0.728383       1   0  0.935159 -0.841918    0        1  0.499898      0
# 4  0.839089       0   0  0.364848  0.919336    1        1 -1.905464      0
#
#     oldpeak  slope  ca  thal  target
# 0 -0.037124      2   2     3       0
# 1  1.773958      0   0     3       0
# 2  1.342748      0   0     3       0
# 3 -0.899544      2   1     3       0
# 4  0.739054      1   3     2       0

# %%
#Splitting the Features and Target

X = data.drop(columns='target', axis=1) #axis=0 refers to operations along the rows (vertical axis), while axis=1 refers to operations along the columns
Y = data['target']

# %%
print(X)
# Out:
#           age  gender  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0   -0.267966       1   0 -0.376556 -0.667728    0        1  0.806035      0
# 1   -0.157260       1   0  0.478910 -0.841918    1        0  0.237495      1
# 2    1.724733       1   0  0.764066 -1.403197    0        1 -1.074521      1
# 3    0.728383       1   0  0.935159 -0.841918    0        1  0.499898      0
# 4    0.839089       0   0  0.364848  0.919336    1        1 -1.905464      0
# ..        ...     ...  ..       ...       ...  ...      ...       ...    ...
# 723  1.503322       0   2 -0.661712 -0.687083    0        0 -1.511859      0
# 733 -1.153610       0   2 -1.346085 -2.041893    0        1  1.112172      0
# 739 -0.267966       1   0 -0.205463  0.164513    0        1  0.499898      1
# 843  0.506972       1   3  1.619532  0.512893    0        0 -1.074521      0
# 878 -0.046555       1   0 -0.661712 -1.132235    0        1 -1.599327      0
#
#       oldpeak  slope  ca  thal
# ...

# %%
print(Y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 723    1
# 733    1
# 739    0
# 843    0
# 878    0
# Name: target, Length: 302, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=0)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (302, 13) (241, 13) (61, 13)

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# accuracy on training data
X_train_prediction = dt.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
 #accuracy on test data
X_test_prediction = dt.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.7704918032786885

# %%
def precision_recall_f1_score(true_labels, pred_labels):

    precision_value = precision_score(true_labels, pred_labels)
    recall_value = recall_score(true_labels, pred_labels)
    f1_score_value = f1_score(true_labels, pred_labels)

    print('Precision =',precision_value)
    print('Recall =',recall_value)
    print('F1 Score =',f1_score_value)
    
# classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision = 1.0
# Recall = 1.0
# F1 Score = 1.0
# Precision = 0.7894736842105263
# Recall = 0.8333333333333334
# F1 Score = 0.8108108108108109

# %% [markdown]
# # Logistic Regression

# %%
log = LogisticRegression()

# %%
#learning model
# training the LogisticRegression model with Training data
log.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = log.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.8547717842323651

# %%
 #accuracy on test data
X_test_prediction = log.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.8524590163934426

# %%
def precision_recall_f1_score(true_labels, pred_labels):

    precision_value = precision_score(true_labels, pred_labels)
    recall_value = recall_score(true_labels, pred_labels)
    f1_score_value = f1_score(true_labels, pred_labels)

    print('Precision =',precision_value)
    print('Recall =',recall_value)
    print('F1 Score =',f1_score_value)
    
 # classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision = 0.8345323741007195
# Recall = 0.90625
# F1 Score = 0.8689138576779026
# Precision = 0.8648648648648649
# Recall = 0.8888888888888888
# F1 Score = 0.8767123287671232

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
# accuracy on training data
X_train_prediction = rf.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
 #accuracy on test data
X_test_prediction = rf.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.8032786885245902

# %%
def precision_recall_f1_score(true_labels, pred_labels):

    precision_value = precision_score(true_labels, pred_labels)
    recall_value = recall_score(true_labels, pred_labels)
    f1_score_value = f1_score(true_labels, pred_labels)

    print('Precision =',precision_value)
    print('Recall =',recall_value)
    print('F1 Score =',f1_score_value)
    
# classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision = 1.0
# Recall = 1.0
# F1 Score = 1.0
# Precision = 0.8157894736842105
# Recall = 0.8611111111111112
# F1 Score = 0.8378378378378378

# %%
#tast case 
new_data =pd.DataFrame({
'age':52,
'gender':1,
'cp':0,
'trestbps':125, 
'chol':212,
'fbs':0,
'restecg':1,
'thalach':168,
'exang':0,
'oldpeak':1.0,
'slope':2,
'ca':2,
'thal':3
},index= [0])

# %%
new_data
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52       1   0       125   212    0        1      168      0      1.0
#
#    slope  ca  thal
# 0      2   2     3

# %%
p = log.predict(new_data)
if p[0]==0:
    print("No Disease")
else:
    print("Disease")
# Out:
# Disease

# %% [markdown]
# # save model using joblib

# %%
import joblib
joblib.dump(log,"model_joblib_heart")
model=joblib.load("model_joblib_heart")
model.predict(new_data)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # GUI

# %%
from tkinter import *
import joblib

# %%
import tkinter as tk  # Importing tkinter module

def show_entry_fields():
    p1 = int(e1.get()) 
    p2 = int(e2.get()) 
    p3 = int(e3.get())
    p4 = int(e4.get()) 
    p5 = int(e5.get()) 
    p6 = int(e6.get())
    p7 = int(e7.get()) 
    p8 = int(e8.get())
    p9 = int(e9.get())
    p10 = int(e10.get())
    p11 = int(e11.get()) 
    p12 = int(e12.get())
    p13 = int(e13.get())
    model = joblib.load("model_joblib_heart")
    result = model.predict([[p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13]])

    if result == 0:
        tk.Label(master,
                 font = ('Kristen ITC' , 14 ),
                 bg="#e6f3fc",
                 fg='green',
                 text="No Heart Diseases").grid(row=31) 
    else:
        tk.Label(master,
                 font = ('Kristen ITC' , 14 ),
                 bg="#e6f3fc",
                 fg='red',
                 text="Possibility of Heart Diseases").grid(row=31)

master = tk.Tk()  # Creating Tkinter window
master.title("Heart Diseases Prediction System")
master.geometry("400x580")
master.config(background="#e6f3fc")
master.resizable(False, False) 

# Labels and Entry Widgets for user input
tk.Label(master,
         font = ('Kristen ITC' , 16 , 'bold'),
         text="Heart Diseases Prediction System", bg="#e6f3fc", fg="black").grid(row=0, columnspan= 2)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Your Age").grid(row=1)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Male Or Female [1/0]").grid(row=2)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of CP").grid(row=3)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of trestbps").grid(row=4)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of chol").grid(row=5)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of fbs").grid(row=6)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of restecg").grid(row=7)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of thalach").grid(row=8)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of exang").grid(row=9)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of oldpeak").grid(row=10)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of slope").grid(row=11)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of ca").grid(row=12)
tk.Label(master,
         font = ('Kristen ITC' , 14 ),
         bg="#e6f3fc",
         text="Enter Value of thal").grid(row=13)


# Entry widgets for user input
e1 = tk.Entry(master)
e2 = tk.Entry(master)
e3 = tk.Entry(master)
e4 = tk.Entry(master)
e5 = tk.Entry(master)
e6 = tk.Entry(master)
e7 = tk.Entry(master)
e8 = tk.Entry(master)
e9 = tk.Entry(master)
e10 = tk.Entry(master)
e11 = tk.Entry(master)
e12 = tk.Entry(master)
e13 = tk.Entry(master)


# Placing Entry widgets in grid
e1.grid(row=1,column=1)
e2.grid(row=2,column=1)
e3.grid(row=3,column=1)
e4.grid(row=4,column=1)
e5.grid(row=5,column=1)
e6.grid(row=6,column=1)
e7.grid(row=7,column=1)
e8.grid(row=8,column=1)
e9.grid(row=9,column=1)
e10.grid(row=10,column=1)
e11.grid(row=11,column=1)
e12.grid(row=12,column=1)
e13.grid(row=13,column=1)


# Place more Entry widgets for other inputs as needed...

# Button to trigger prediction
tk.Button(master, 
           font = ('Kristen ITC' , 16 , 'bold' ),
           bg="#fcefe6" ,
           fg='black' ,
           activeforeground = 'black' ,
           activebackground = '#fcefe6',
           text='Predict', command=show_entry_fields).grid(row=30, column=1)

mainloop()  # Running Tkinter event loop
